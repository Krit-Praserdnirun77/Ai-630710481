# %%
# !pip install -U pip transformers
# Out:
# Requirement already satisfied: pip in /usr/local/lib/python3.12/dist-packages (24.1.2)
# Collecting pip
#   Downloading pip-25.2-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (4.56.2)
# Collecting transformers
#   Downloading transformers-4.57.0-py3-none-any.whl.metadata (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.4/41.4 kB 2.4 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers) (3.19.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.35.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers) (2.32.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.6.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (2025.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (1.1.10)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2025.8.3)
# Downloading pip-25.2-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 13.9 MB/s eta 0:00:00
# Downloading transformers-4.57.0-py3-none-any.whl (12.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 24.4 MB/s eta 0:00:00
# Installing collected packages: pip, transformers
#   Attempting uninstall: pip
#     Found existing installation: pip 24.1.2
#     Uninstalling pip-24.1.2:
#       Successfully uninstalled pip-24.1.2
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.56.2
#     Uninstalling transformers-4.56.2:
#       Successfully uninstalled transformers-4.56.2
# Successfully installed pip-25.2 transformers-4.57.0

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

# %%
checkpoint = 'facebook/nllb-200-distilled-600M'
tokenizer = AutoTokenizer.from_pretrained(checkpoint)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/564 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/4.85M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.3M [00:00<?, ?B/s]
# special_tokens_map.json: 0.00B [00:00, ?B/s]

# %%
print(f"{len(tokenizer.vocab)}\n")

tokenizer.vocab
# Out:
# 256204
# {'▁Vais': 58656,
#  '▁సము': 170806,
#  '▁боловч': 137751,
#  '▁leban': 238946,
#  '▁profile': 137642,
#  'しまいます': 85570,
#  'raga': 24304,
#  '▁dôkaz': 216753,
#  '▁kock': 200517,
#  '▁מצי': 134829,
#  'あまりにも': 152732,
#  '▁sifat': 35530,
#  '▁किहा': 208830,
#  'amentul': 166799,
#  '▁nesesè': 149607,
#  '▁aspett': 99160,
#  '▁कने': 107688,
#  '▁ಮುಂದೆ': 92908,
#  '▁πλευ': 168761,
#  '▁Sinh': 214377,
#  '▁तों': 173971,
#  '▁داوای': 78639,
#  'ambili': 20347,
#  '▁shingkang': 231027,
#  '▁ago': 13201,
#  '▁надеж': 201386,
#  'ನ್ಸ': 101136,
#  '▁Persi': 223337,
#  '▁வே': 7880,
#  '▁kort': 23328,
#  'ブロックチェーン': 156755,
#  '▁mmušo': 141218,
#  '▁kɛwalew': 194256,
#  '▁ýylda': 114597,
#  '▁Miyambo': 226250,
#  '▁втори': 181661,
#  '▁промене': 181514,
#  'ạc': 21130,
#  '▁drejtat': 241417,
#  '▁ném': 191479,
#  '▁زالىم': 116782,
#  'SL': 141297,
#  'ruik': 13965,
#  '▁Orig': 75125,
#  'ста': 722,
#  '▁العم': 132752,
#  '▁sibẹ': 228339,
#  '▁memungkinkan': 50198,
#  '▁fixed': 191059,
#  'ésére': 78826,
#  '▁وح': 36674,
#  'โอกาส': 183399,
#  'odzimodzi': 235608,
#  '▁fahren': 212884,
#  'ၥ': 254086,
#  '▁faneleke': 45962,
#  '▁laatste': 83124,
#  '▁ጠንካራ': 216742,
#  '▁चलते': 133855,
#  '▁68': 31600,
#  '▁살게': 236337,
#  '赴': 254644,
#  '▁ম্যাচ': 217211,
#  'esc': 16138,
#  '▁உன': 68408,
#  '▁ddinas': 133664,
#  '▁نج': 30760,
#  '▁aliwa': 98720,
#  '▁conform': 30309,
#  'ញ្ញាណ': 142503,
#  'าส': 55594,
#  'тарынан': 203372,
#  '▁embeera': 163927,
#  'Nin': 150332,
#  '変わらない': 242613,
#  'اجاق': 18122,
#  '▁gullukçy': 101315,
#  '▁suicide': 192297,
#  '▁kris': 41306,
#  'bbui': 230579,
#  '▁سح': 221363,
#  '▁μιλήσω': 178531,
#  '▁түүнийг': 86609,
#  '詭': 255765,
#  '▁δυο': 103520,
#  '適応': 153632,
#  'lar': 291,
#  '▁მედი': 221546,
#  'と言われ': 240611,
#  '拘束': 171028,
#  '▁gaji': 88824,
#  '▁گەرد': 237747,
#  '▁חלק': 58414,
#  '▁paskat': 184472,
#  'ለብ': 218559,
#  '▁다윗': 114414,
#  '▁bosque': 241221,
#  '▁dibokeng': 220120,
#  '▁जाइ': 28656,
#  '▁útil': 100968,
#  '▁fiosrachadh': 179214,
#  '▁mensaje': 189668,
#  '▁вистински': 188893,
#  'ayiro': 190917,
#  '▁látogat': 164715,
#  '▁Կ': 17251,
#  '▁cięż': 145859,
#  'cessen': 155313,
#  '▁kutya': 80284,
#  '▁கொடு': 80331,
#  'dzɔ': 46279,
#  'pewa': 132256,
#  '▁joie': 155820,
#  'する権利': 229140,
#  '▁feletšego': 138254,
#  '▁Herodes': 96819,
#  '▁haute': 170661,
#  'မလား': 177999,
#  '▁profètas': 66570,
#  '▁dié': 73823,
#  '▁chuideachadh': 245165,
#  '▁istilah': 83456,
#  '▁nekom': 154964,
#  '▁kebakaka': 239190,
#  '▁වච': 112571,
#  '▁trabaj': 128750,
#  '▁vanua': 30558,
#  '▁limu': 163583,
#  'kini': 97571,
#  '▁ମଣିଷ': 124099,
#  '▁स्वाद': 243021,
#  '▁ropui': 110616,
#  '▁ایل': 186254,
#  '▁Žmonės': 235257,
#  '▁helping': 186108,
#  'liť': 118975,
#  '▁Damon': 200885,
#  'imbang': 44370,
#  'सिड': 219858,
#  '▁vitit': 72721,
#  'گران': 58510,
#  'מוד': 38798,
#  '▁औ': 1709,
#  '▁kapital': 38178,
#  'קט': 15442,
#  '▁නිස': 186557,
#  '▁እኳ': 71726,
#  'கின்ற': 44835,
#  'hui': 15510,
#  'ләренә': 40543,
#  '▁Қа': 5550,
#  '▁tex': 20236,
#  'াবলৈ': 137940,
#  'བྲོས་': 221975,
#  'ルール': 90191,
#  '▁joge': 188603,
#  'sɔ': 7187,
#  'xesha': 15905,
#  '▁Kikristo': 142582,
#  '▁जसको': 239475,
#  '▁Vyriaus': 227911,
#  'apas': 18991,
#  '▁deroga': 222763,
#  '起訴': 234116,
#  'вини': 75370,
#  '▁noslēg': 132566,
#  'ambur': 205228,
#  '▁ଶାନ୍ତି': 185203,
#  'àth': 94694,
#  '▁libros': 106137,
#  '▁һеҙгә': 75605,
#  '▁ឡ': 149166,
#  '▁बॉक्स': 168866,
#  'nama': 40182,
#  '▁massempajang': 219119,
#  '▁بهداشتی': 194686,
#  '▁nggo': 141619,
#  'కూడదు': 131372,
#  'ugen': 75767,
#  '▁bees': 199930,
#  'stora': 244667,
#  'żi': 7752,
#  '▁Täna': 241338,
#  'eddi': 44056,
#  'nera': 63856,
#  'ုပ်တို့': 60867,
#  '▁Rådet': 79069,
#  'öffent': 135601,
#  'benefiċ': 200321,
#  'okum': 102320,
#  '▁амерички': 243855,
#  'تاپ': 161284,
#  '▁vetes': 203366,
#  'ukora': 237083,
#  'тоо': 94568,
#  '材': 251389,
#  '▁كەلم': 103908,
#  'Რ': 255993,
#  '烧': 254036,
#  'མི་དམངས་': 144215,
#  '▁hoon': 244129,
#  'akot': 42254,
#  '▁kabat': 207804,
#  '▁ಹಾಸ': 215095,
#  'urian': 203715,
#  '▁Lentsoe': 166809,
#  '▁здат': 109035,
#  '▁Nib': 64319,
#  'esť': 75719,
#  '▁operators': 234093,
#  '▁upande': 111142,
#  'กิจ': 204687,
#  '▁1;': 154640,
#  '▁etildi': 109412,
#  '▁RV': 227647,
#  'mağı': 186879,
#  '▁సమయంలో': 59852,
#  'の高': 162828,
#  '▁استخدام': 102080,
#  '8/': 27007,
#  '▁Kuid': 62005,
#  '▁výrobku': 187730,
#  'миләр': 239090,
#  '▁Ninive': 199174,
#  'τω': 19360,
#  'баста': 201110,
#  '▁érd': 29328,
#  'प्रै': 233624,
#  'kuk': 49118,
#  'ほん': 67583,
#  '▁madz': 145354,
#  '▁eze': 59176,
#  '▁gran': 4710,
#  '▁ناشی': 142735,
#  '▁ভূমিকা': 186101,
#  '▁adicional': 188653,
#  'ແມ່ຍິງ': 236765,
#  '▁උනා': 110721,
#  '▁champ': 92660,
#  'ugwa': 101304,
#  'вані': 109879,
#  '▁Barcha': 243228,
#  '▁bergan': 87493,
#  '▁Nyoe': 141743,
#  '▁تواند': 10370,
#  'But': 137761,
#  '▁مهرباني': 186219,
#  '▁دۆلەت': 101802,
#  '▁ବି': 5308,
#  '▁тэдний': 103808,
#  '▁maħsuba': 156829,
#  '▁فرستاده': 176889,
#  'τερο': 136035,
#  '▁ansa': 44742,
#  '▁eche': 93968,
#  'եցինք': 175624,
#  '▁300.000': 200920,
#  'iew': 197173,
#  'מוך': 129712,
#  'itali': 23696,
#  'DR': 49750,
#  '▁جائے': 22227,
#  '▁ntima': 26646,
#  '▁ପାଇବା': 136615,
#  '▁наф': 99558,
#  '体は': 72490,
#  '▁الر': 6051,
#  '▁egiteko': 89360,
#  '▁θέλεις': 107769,
#  '▁intwaro': 221883,
#  '▁Donn': 217012,
#  '▁вимагає': 215447,
#  '▁주님께서': 110286,
#  '▁тады': 155756,
#  'ছি': 7373,
#  '▁લાગે': 50381,
#  '▁rezultatus': 198955,
#  '魯': 253643,
#  '▁brauche': 160896,
#  '▁geupeurintah': 185808,
#  '花': 251474,
#  '▁እሷ': 143163,
#  'лоди': 220931,
#  'እቲ': 77450,
#  '▁tình': 20614,
#  '▁प': 263,
#  '▁vakayalo': 78141,
#  '▁എ': 2088,
#  '▁երգ': 149849,
#  '▁shay': 165813,
#  '▁ymarfer': 146340,
#  '++': 143450,
#  '▁Pazi': 194523,
#  'iskt': 25424,
#  '▁bawat': 46694,
#  'wersa': 240459,
#  'otāja': 132643,
#  '平台': 240404,
#  '▁10%.': 197321,
#  '▁hundred': 99296,
#  '▁Ini': 8200,
#  '銭': 253767,
#  '▁የአምላክ': 151805,
#  '▁nagbaba': 220873,
#  'ችለው': 133028,
#  'szak': 56649,
#  'tɔn': 19266,
#  '▁hänen': 24810,
#  '▁mvula': 50933,
#  '▁ittana': 123945,
#  'ighet': 159892,
#  'ceği': 90447,
#  '▁קה': 205838,
#  '▁порно': 168634,
#  '▁dor': 9991,
#  'йыҡ': 79108,
#  'forme': 28043,
#  '呆': 255148,
#  'ነጋ': 99910,
#  '▁ئەقىل': 201876,
#  '▁sutartį': 217080,
#  '誉': 252908,
#  '▁analiżi': 207203,
#  '▁твој': 116250,
#  'یرے': 218433,
#  'ક્ષણિક': 218919,
#  '▁אינו': 98697,
#  '▁나와': 53696,
#  'ངེད་': 103865,
#  '▁kasutades': 241985,
#  '潜': 252168,
#  '▁εγκ': 98714,
#  '୍ରମ': 79851,
#  'ojan': 176817,
#  '▁ئەمەللەرنى': 205182,
#  '▁gatan': 185358,
#  'పె': 49504,
#  '▁Рез': 182795,
#  'depodob': 95713,
#  '▁teljes': 27129,
#  '▁kontan': 76242,
#  'ungeun': 203013,
#  '▁vou': 17313,
#  'bewer': 99939,
#  '▁پاي': 42301,
#  '▁કિંમત': 134566,
#  'arus': 62566,
#  'nali': 91337,
#  '▁místě': 200763,
#  '▁grupa': 104359,
#  '▁kører': 218491,
#  'Mint': 114452,
#  '▁tufa': 138346,
#  'MS': 17591,
#  '▁nagsugod': 198614,
#  '▁rant': 159480,
#  '▁moderno': 128250,
#  '▁idegen': 247946,
#  '▁Umsebenzi': 244776,
#  'adilifu': 168786,
#  '経営': 70386,
#  'tt': 862,
#  '▁deda': 99664,
#  '▁ansi': 64320,
#  '込': 250638,
#  'ults': 134922,
#  '▁28,': 61634,
#  'ചെയ്യ': 136420,
#  'لئي': 193300,
#  '▁Vs': 164103,
#  '▁աշակերտ': 211660,
#  '▁Α': 4730,
#  '▁èrò': 83826,
#  '▁algú': 151702,
#  'Kay': 99620,
#  '▁पुन्हा': 59014,
#  '▁اولدوغو': 148769,
#  '雇用': 64270,
#  'уште': 240949,
#  'ເດັກນ້ອຍ': 192292,
#  'க்குப்': 176486,
#  '▁държа': 45984,
#  '▁bagaimana': 19250,
#  'раҡ': 29758,
#  'Mátíù': 235173,
#  '▁gemens': 76429,
#  'селек': 166693,
#  '力の': 78470,
#  'chem': 59803,
#  'larıyla': 133237,
#  'adla': 117696,
#  '▁paragraph': 78384,
#  'әнн': 79533,
#  'oleng': 202467,
#  '▁idi': 4864,
#  '▁بولساق': 234572,
#  '▁Ikke': 45974,
#  'ధం': 147906,
#  '▁воск': 124142,
#  '▁bwacu': 144088,
#  '▁要': 50101,
#  'རྒྱུན་དུ་': 146681,
#  '▁návr': 116086,
#  'ıyor': 16506,
#  'gun': 2876,
#  '▁dzīvē': 153270,
#  'ören': 57753,
#  '▁Cash': 121180,
#  'loko': 31183,
#  '▁exceeded': 1989,
#  '▁그에게': 37787,
#  '▁Expert': 203884,
#  'paɣ': 32207,
#  '▁თანამ': 144208,
#  '▁Hiroshima': 230540,
#  '▁Bulgaria': 115157,
#  '▁ਲੱਗਾ': 237588,
#  '▁Благо': 75035,
#  'ブラック': 137598,
#  '▁காரணமாக': 188881,
#  'odon': 104141,
#  '▁tempora': 164580,
#  'isuma': 103370,
#  'ቷል': 100412,
#  '▁ሸ': 63423,
#  '▁taybet': 145888,
#  '▁Newcastle': 196591,
#  'tla': 134134,
#  '▁রু': 205468,
#  '▁ван': 117196,
#  '▁Hund': 108922,
#  '▁ଆର୍ଥିକ': 141940,
#  'ସା': 41576,
#  'umon': 147915,
#  '▁korpor': 86187,
#  'istean': 182138,
#  '▁miteny': 152291,
#  '▁ايل': 239251,
#  '▁പ്രത്യേക': 93533,
#  '▁عملية': 244002,
#  '▁брати': 210031,
#  '▁kasadonyo': 121888,
#  '▁不': 20632,
#  '▁kursi': 121072,
#  'bo': 298,
#  '▁dujų': 175536,
#  'でしたか': 197100,
#  '▁perila': 117598,
#  '▁pažeid': 102654,
#  '▁הכסף': 162956,
#  '▁répondit': 169275,
#  '▁budu': 35981,
#  '▁tinga': 51849,
#  '▁pɔ': 19154,
#  '▁Peyğəmbər': 146282,
#  '▁затра': 196564,
#  '▁tati': 83679,
#  '▁Paw': 11460,
#  '▁alë': 77495,
#  'ticos': 23751,
#  '▁ବେଶ': 103901,
#  '▁ништо': 89920,
#  '▁sąly': 39058,
#  '▁হঠ': 137882,
#  '▁eona': 26254,
#  '▁वायरस': 212595,
#  '▁hansara': 64398,
#  '▁forbe': 174648,
#  '▁sefe': 95348,
#  'ཚོད་': 32640,
#  '欲しい': 46424,
#  'ᱨ': 250092,
#  'тылды': 187210,
#  '▁당사는': 226448,
#  '▁kambele': 246437,
#  '▁સ્થ': 22708,
#  '▁പ്ല': 124905,
#  '▁mupashi': 135423,
#  'ѐ': 252683,
#  '▁حديث': 224747,
#  '▁яхшы': 27838,
#  '▁Modern': 84032,
#  'tech': 32529,
#  '▁әйте': 182624,
#  'ิตย์': 187605,
#  'サービ': 19664,
#  'ឭ': 255978,
#  'ገኛ': 53746,
#  '▁Roj': 160854,
#  '▁sard': 144658,
#  '▁jikkontrib': 195793,
#  '▁ప్రయత్': 55193,
#  'lmo_Latn': 256106,
#  '▁danes': 78084,
#  '▁dôvodu': 157535,
#  '▁mtendere': 140512,
#  '▁wĩtĩkio': 152488,
#  '▁áðü': 206737,
#  'aganiza': 194978,
#  'ႄ': 250098,
#  '▁extraño': 243637,
#  '▁լուս': 140430,
#  'utauvata': 236274,
#  '▁ໂ': 13251,
#  '▁athör': 72391,
#  'wszy': 225341,
#  'tali': 6180,
#  'కాశ': 65872,
#  '▁mwyn': 44779,
#  'ያት': 42120,
#  '▁பிற': 39742,
#  '▁دوران': 38412,
#  '▁forbi': 181114,
#  '▁cusub': 103717,
#  'ەيدۇ': 55697,
#  'द्य': 10573,
#  '▁кешеләрне': 89947,
#  '▁wraig': 177937,
#  '▁အကြောင်း': 49151,
#  '▁Matan': 192574,
#  '▁ebinom': 121877,
#  '▁qaldır': 184719,
#  '▁ਕੋ': 11531,
#  '▁تول': 15181,
#  'akami': 138167,
#  'פּס': 227644,
#  '▁tokią': 211103,
#  '▁oom': 165228,
#  '▁ئەھلى': 108623,
#  'erner': 112928,
#  '▁તાજેતર': 181136,
#  '▁Vatik': 218921,
#  '▁şü': 59711,
#  '▁anor': 104775,
#  '▁җыелыш': 149893,
#  '아무': 239587,
#  'પ્સ': 143561,
#  '▁nemajú': 195526,
#  'neb': 36344,
#  '▁алардын': 51477,
#  '▁najti': 223026,
#  '▁naprawdę': 81659,
#  '▁gyűjt': 204486,
#  '▁lôn': 28888,
#  '▁cuando': 15574,
#  '▁duu': 74441,
#  '▁rèkko': 204108,
#  '▁wenyine': 215319,
#  '▁était': 16817,
#  'fä': 65454,
#  'ình': 3186,
#  'emma': 98576,
#  'པ་རེད།': 176944,
#  '▁zee': 193663,
#  'فس': 46347,
#  '▁rei': 14304,
#  '▁ସୁରକ୍ଷା': 113575,
#  '▁berätta': 160247,
#  'ayet': 82364,
#  '▁dɩ': 38381,
#  '▁قەۋمى': 76612,
#  '▁Оваа': 104806,
#  '▁해결할': 185951,
#  '▁lakòz': 193477,
#  'याल': 207239,
#  '▁PIN': 164977,
#  '▁원': 7345,
#  'fo': 1108,
#  '▁ਦੌਰ': 64209,
#  '▁կհ': 135621,
#  'אַטי': 126487,
#  '▁ଚାକିରି': 245476,
#  '普及': 165867,
#  'effa': 118416,
#  '▁분야에서': 144837,
#  '▁nikatsongo': 218423,
#  '時は': 54661,
#  'zij': 58610,
#  '▁bikalulu': 89386,
#  '▁Paulu': 25868,
#  'cao': 90963,
#  '▁사실상': 151700,
#  '▁lush': 170465,
#  '▁단계': 37179,
#  '▁ⴳ': 28127,
#  '▁тога': 31661,
#  '하던': 105178,
#  '▁Jestli': 83450,
#  '附近': 172473,
#  '▁ive': 221377,
#  '▁abinci': 76953,
#  'ູກ': 49239,
#  '▁napravio': 146626,
#  '▁շատ': 22420,
#  '▁kurie': 21273,
#  '▁olonjali': 94225,
#  '▁irányelv': 107369,
#  '▁Anat': 180110,
#  '▁jurul': 231263,
#  'вӣ': 199210,
#  'Би': 48018,
#  'ụrụ': 5681,
#  '▁دانشگاه': 45710,
#  '▁akasa': 244515,
#  'piej': 97175,
#  'ಬೇಕಾದ': 120935,
#  '▁ymisk': 182832,
#  'лі': 895,
#  '▁بگۆڕ': 180807,
#  '▁Bureau': 127351,
#  '▁মোৰ': 19542,
#  'గే': 48445,
#  '▁тикшереү': 241434,
#  '▁Nej': 39395,
#  '▁seconda': 104403,
#  '▁nasayaat': 110006,
#  'baik': 18089,
#  '▁жасалады': 226532,
#  '▁Nokia': 86586,
#  '▁kanki': 139455,
#  '玻': 254414,
#  'くと': 115746,
#  'домо': 136694,
#  '差別': 93374,
#  '▁güven': 53194,
#  'ikel': 65929,
#  '▁죽일': 206446,
#  '▁매달': 209442,
#  'loi': 141426,
#  '▁వ్యవస్థ': 98032,
#  '▁Munthu': 93629,
#  '▁Banc': 223481,
#  '▁həyata': 195640,
#  '▁bertanya': 60619,
#  '▁tingana': 183748,
#  '▁منهنجو': 97041,
#  '▁ionad': 134111,
#  'dheala': 131833,
#  '▁niebezpie': 245156,
#  'ীরে': 209432,
#  '▁gələ': 87691,
#  'ઇ': 249621,
#  '▁ائمان': 61334,
#  '▁قاي': 16723,
#  'etsɔ': 151990,
#  '▁kupa': 67360,
#  '▁ئىشىنى': 136508,
#  '▁ત્રી': 178104,
#  '▁delež': 231115,
#  '▁국민': 67008,
#  '▁çfarë': 44021,
#  '▁seega': 154219,
#  '▁mụtara': 215014,
#  '▁asiti': 97398,
#  '틱': 252879,
#  '▁نەرسىگە': 180659,
#  'ያ።': 193951,
#  'اره': 4144,
#  '▁ئايال': 40625,
#  'ច្ចុប្ប': 169705,
#  'እን': 73873,
#  'ugt': 47463,
#  '然而': 228116,
#  '▁ಮಾಡುವುದು': 142750,
#  '▁Macht': 181303,
#  '▁aconteceu': 102886,
#  '▁pangalaman': 181788,
#  '▁себеп': 50324,
#  '୍ଚ': 13540,
#  'ọn': 1154,
#  '▁spis': 194417,
#  '▁죽었다': 218596,
#  'ယူႇ': 43699,
#  '▁Шайтан': 58735,
#  'ໃສ': 48008,
#  '▁халқы': 130095,
#  '▁बह': 27757,
#  '概念': 64317,
#  '▁हावे': 120215,
#  '▁kũla': 117385,
#  '▁gyvenime': 168316,
#  '▁ၶွင်': 216741,
#  '▁يولا': 213540,
#  'ɲuman': 46772,
#  'འོངམ་ད་': 245646,
#  '▁Cain': 210932,
#  'enske': 54498,
#  'пка': 54191,
#  '▁tänä': 178798,
#  '▁blanco': 219228,
#  '▁jaote': 244161,
#  '▁қабылдаған': 243462,
#  'ிருந்தது': 167220,
#  '▁dirileng': 168720,
#  '▁ਐਲ': 132301,
#  '▁ndza': 69262,
#  '▁efeito': 156665,
#  '▁एला': 170627,
#  '▁באש': 212690,
#  '▁ngawe': 204354,
#  '▁lunak': 85274,
#  'ଣ୍ଡ': 27160,
#  '香港': 116976,
#  '▁eks': 5727,
#  '▁ટા': 225331,
#  '柄': 252331,
#  '▁demektir': 231322,
#  'ူ': 248749,
#  '▁kollha': 18907,
#  '▁түзету': 195204,
#  '▁набуд': 203496,
#  '▁delili': 159849,
#  '▁kamatayon': 110526,
#  '有一個': 177889,
#  'olu': 2198,
#  '▁kracht': 188346,
#  'ਿਕਸ': 235468,
#  'ဂ္ဂ': 212528,
#  'ИН': 145548,
#  'itè': 169287,
#  'ztal': 176732,
#  'nanga': 189945,
#  '▁꾸': 61461,
#  '이었': 31754,
#  '▁Italia': 30991,
#  'ittiin': 232996,
#  '▁ribų': 235846,
#  '▁ұста': 65718,
#  '▁ડ્રાઇવ': 233721,
#  'šies': 104969,
#  '▁thinlung': 162157,
#  'とともに': 71482,
#  '▁območ': 86789,
#  '▁Salomone': 143098,
#  '▁omwen': 236056,
#  '▁రా': 13550,
#  '▁اول': 3989,
#  '▁runga': 19370,
#  'صب': 158843,
#  '▁chithandizo': 194906,
#  '▁5:14)': 138453,
#  '▁harusu': 46908,
#  '▁olmadığı': 167229,
#  '▁kadai': 62817,
#  '▁vè': 114551,
#  '▁шавад': 71157,
#  '単なる': 118040,
#  'ungue': 230616,
#  '▁गा': 11612,
#  '▁આવો': 221525,
#  '▁तेव्हा': 46261,
#  '▁يعيشك': 219220,
#  '▁sén': 244103,
#  '▁Здесь': 178321,
#  '▁بیٹے': 170289,
#  '▁മഹ': 112894,
#  'mais': 73009,
#  '▁တေလႆႈ': 182444,
#  '▁oleme': 64212,
#  '▁emléks': 242846,
#  '▁mage': 51271,
#  '▁공장': 209954,
#  'ască': 49567,
#  '▁basaba': 245834,
#  '▁pertinentes': 200703,
#  '▁draugi': 152290,
#  'шөөр': 123665,
#  'וק': 6528,
#  '▁دووەم': 139459,
#  'рок': 11361,
#  '▁Atâa': 161232,
#  '▁wɔanya': 193721,
#  '▁aur': 14693,
#  '▁deva': 195596,
#  '▁vp': 117837,
#  '▁skirtas': 148084,
#  '▁hevitra': 67058,
#  'urisa': 158630,
#  '▁غريب': 137548,
#  'קומען': 43775,
#  '▁láàárín': 101463,
#  '匙': 255616,
#  '▁Tweet': 163519,
#  '▁aloqa': 136888,
#  '▁किलो': 147532,
#  '▁školi': 222746,
#  '▁چییە': 132363,
#  '▁മ': 2746,
#  'ڭگە': 182482,
#  '▁керекти': 132964,
#  '▁transe': 189082,
#  'ừa': 33808,
#  '▁imitima': 157335,
#  '▁unod': 211864,
#  '▁lepšie': 87555,
#  'వు': 7513,
#  '▁skema': 177563,
#  '▁gesteld': 182254,
#  '▁décembre': 163765,
#  '▁अॅ': 169478,
#  '將': 250854,
#  'แก้': 153310,
#  '▁sédd': 211470,
#  '▁ලඟ': 232395,
#  '▁یکسان': 176864,
#  '▁Groot': 208052,
#  'ঠা': 238877,
#  'ėjimą': 79039,
#  '▁Lefè': 188295,
#  '▁Haman': 158366,
#  'annde': 122154,
#  'ါ': 248867,
#  '▁ٽيڪنالاجي': 239890,
#  '▁Yala': 74371,
#  '▁sũur': 42650,
#  'fó': 161197,
#  '▁роках': 214000,
#  '▁henkilökohta': 234949,
#  'ält': 34768,
#  '▁százal': 98443,
#  '▁produit': 106663,
#  '▁아름답': 131918,
#  'ighter': 178309,
#  '▁sikat': 153748,
#  'wá': 81381,
#  '▁Уз': 103131,
#  'ێ': 248417,
#  '▁palvel': 53411,
#  '▁نفسي': 144439,
#  '▁hoa': 31578,
#  '▁ياكى': 33233,
#  '▁هذا': 6277,
#  'cleachdaidh': 153897,
#  '▁بارودۆ': 194355,
#  '▁Double': 181764,
#  '▁burtur': 102882,
#  '领域': 109270,
#  '▁nafn': 180011,
#  '▁relativi': 168495,
#  '▁nhia': 82005,
#  '▁яҙ': 54691,
#  'ဖြင့်': 71315,
#  '▁길을': 44492,
#  'lader': 239633,
#  'älla': 30799,
#  'onaka': 51400,
#  '▁দোকান': 227132,
#  'organisation': 123989,
#  '▁akyldar': 207078,
#  '▁hadlay': 142971,
#  'soali': 89988,
#  '▁mmienu': 110370,
#  '有罪': 192532,
#  'ары': 75988,
#  'ynen': 180301,
#  '▁oñemb': 147229,
#  '▁Efisɛ': 175462,
#  '▁μελών': 158892,
#  'ლისა': 167404,
#  '▁ፈተና': 141198,
#  'ĩkorwo': 232803,
#  '▁wakatu': 216237,
#  '▁filme': 62724,
#  'wun': 11339,
#  '▁ዝሓ': 54923,
#  '令': 250728,
#  '▁ਜਨ': 56357,
#  '▁Evet': 44882,
#  '̍': 255235,
#  'enseignement': 177688,
#  'catu': 149109,
#  '▁Nor': 6546,
#  'letan': 150561,
#  'gape': 138552,
#  '▁pelong': 93630,
#  '▁калышы': 198487,
#  'ནི་ཨིན་': 103802,
#  'りを': 43461,
#  '▁erkän': 193904,
#  '▁économiques': 232027,
#  'ogr': 19130,
#  'ாம': 28263,
#  '▁eyak': 184527,
#  '▁нещо': 24727,
#  '▁خراپ': 77402,
#  '▁тейеш': 41593,
#  '▁notti': 243011,
#  'ڕه': 69335,
#  'འཁྲ': 28489,
#  '▁باشقا': 34176,
#  '▁지역을': 234158,
#  '▁fiiele': 97563,
#  'rition': 194008,
#  'sonkhano': 127755,
#  '▁कइले': 129040,
#  'enses': 58655,
#  '▁nǔ': 6560,
#  'esiya': 63521,
#  '▁буд': 22146,
#  '▁ие': 69311,
#  '▁Ced': 228626,
#  'ពីរ': 59953,
#  '▁forbindelser': 208778,
#  'чком': 108782,
#  '▁korrald': 122699,
#  '▁tår': 193204,
#  'σης': 9751,
#  '▁гледате': 245685,
#  'שהו': 19002,
#  '負け': 213208,
#  '▁Tind': 129944,
#  '▁batyr': 190830,
#  '▁ଘଣ୍ଟ': 140492,
#  '宮': 252473,
#  'عام': 61838,
#  '이사': 241456,
#  'udre': 238382,
#  '▁तुमन': 42066,
#  '▁tose': 145512,
#  '▁ලියන්න': 175126,
#  '▁둘': 23050,
#  '▁jiwaray': 223555,
#  'zilgan': 75651,
#  'хээр': 74021,
#  'habhatidzwa': 223256,
#  '▁əvvəl': 61419,
#  '▁stóra': 218793,
#  '▁Ethiopia': 122052,
#  '▁hiko': 119681,
#  '▁ෂ': 127718,
#  '賦': 255544,
#  '▁piutt': 196679,
#  '幫助': 134913,
#  '▁mbo': 7136,
#  '▁ipag': 165811,
#  'ovis': 90448,
#  '▁angg': 35541,
#  '▁अमेरिक': 119662,
#  'ო': 248482,
#  '▁rein': 51614,
#  '▁dific': 48608,
#  '求め': 30352,
#  '▁oder': 8917,
#  '▁dold': 146711,
#  'länderna': 224657,
#  'filipiya': 191849,
#  '▁Körper': 208082,
#  '▁lingkod': 236102,
#  '▁Bize': 164536,
#  '▁wrthych': 244027,
#  '▁ಊ': 79443,
#  '▁దాని': 32494,
#  '▁مەد': 134546,
#  '▁খুজি': 243189,
#  '▁அ': 1202,
#  'NP': 84364,
#  '▁dikirim': 96865,
#  'ieux': 180392,
#  'нәре': 92283,
#  'アドバイス': 118466,
#  '▁ஊ': 41653,
#  '▁ocipepi': 122349,
#  'ۆنا': 102402,
#  '▁savan': 215417,
#  'ôh': 18840,
#  '▁환자의': 221385,
#  '▁њен': 144593,
#  'порту': 236374,
#  'caan': 124446,
#  '▁アッラー': 123857,
#  '▁sosial': 22735,
#  'ताओं': 87363,
#  'chool': 14209,
#  'ឈប់': 213217,
#  '▁ଯେମିତି': 220576,
#  '▁kendini': 105533,
#  'boy': 56949,
#  '▁problemă': 203901,
#  '▁jidde': 100341,
#  'kop': 17367,
#  'гнете': 161824,
#  'Commerce': 166965,
#  '▁progress': 75198,
#  '▁soso': 125366,
#  '▁განვითარ': 149620,
#  '▁افسر': 220051,
#  '▁slimības': 127141,
#  '▁נוצן': 108863,
#  'дері': 29121,
#  '▁بىرى': 39604,
#  '▁kooperazzjoni': 192742,
#  'τον': 35454,
#  '▁viest': 131974,
#  'opati': 204723,
#  '▁tlwaelegileng': 242345,
#  '▁beku': 65538,
#  '▁ɓangare': 161272,
#  '▁nespráv': 219253,
#  '▁kyaũ': 44248,
#  'ctivo': 63300,
#  ...}

# %%
thai_char_min = 0x0E00
thai_char_max = 0x0E7F

thai_tokens = [
    token for token in tokenizer.vocab.keys()
    if any(thai_char_min <= ord(char) <= thai_char_max for char in token)
]

thai_token_count = len(thai_tokens)
sample_size = 20
thai_tokens_sample = thai_tokens[:sample_size]


print(f"{thai_token_count}\n")
for token in thai_tokens_sample:
  print(token)
# Out:
# 1712
#
# ของเขา
# มิ
# คัญ
# ไอ
# ▁คุณ
# จะทรง
# ง่
# เพ
# ปล่อย
# ํานา
# เก
# ▁พอ
# โ
# นี
# ตํารวจ
# ล่าวว่า
# คนเดียว
# ัญหา
# ▁เร
# ลูก

# %%
import tensorflow as tf
import plotly.graph_objects as go
import plotly.express as px
from plotly.subplots import make_subplots
import numpy as np
import math

# %%
sentence = 'Work hard, play harder'

# %%
cleaned_sentence = sentence.replace(',', '')
cleaned_sentence
# Out:
# 'Work hard play harder'

# %%
words = cleaned_sentence.split()
words
# Out:
# ['Work', 'hard', 'play', 'harder']

# %%
sorted_words = sorted(words)
sorted_words
# Out:
# ['Work', 'hard', 'harder', 'play']

# %%
dc = {word: index for index, word in enumerate(sorted_words)}
dc
# Out:
# {'Work': 0, 'hard': 1, 'harder': 2, 'play': 3}

# %%
sentence_int = tf.constant(
    [dc[s] for s in sentence.replace(',', '').split()],
    dtype=tf.int32
)

# %%
print(sentence)
print(sentence_int)
# Out:
# Work hard, play harder
# tf.Tensor([0 1 3 2], shape=(4,), dtype=int32)

# %%
# สร้าง embedding layer
tf.random.set_seed(123)
vocab_size = 50_000
embedding_dim = 2

embed = tf.keras.layers.Embedding(input_dim=vocab_size, output_dim=embedding_dim)

# %%
embedded_sentence = embed(sentence_int)

# %%
embedded_sentence
# Out:
# <tf.Tensor: shape=(4, 2), dtype=float32, numpy=
# array([[ 0.04274413,  0.02640809],
#        [ 0.04193771,  0.01141412],
#        [-0.01925882,  0.01812642],
#        [ 0.01571875,  0.02884904]], dtype=float32)>

# %%
tf.random.set_seed(123)
vocab_size = 50_000
embedding_dim = 2

dummy_input = tf.constant([0, 1, 2], dtype=tf.int32)

# Case 1 Default initializer (RandomUniform(-0.05, 0.05))
embed_default = tf.keras.layers.Embedding(input_dim=vocab_size, output_dim=embedding_dim)
_ = embed_default(dummy_input) # เรียกใช้งาน layer เพื่อสร้าง weights
weights_default = embed_default.get_weights()[0].flatten()
weights_default.shape
# Out:
# (100000,)

# %%
# Case 2 GlorotUniform initializer
tf.random.set_seed(123)
embed_glorot = tf.keras.layers.Embedding(
    input_dim=vocab_size,
    output_dim=embedding_dim,
    embeddings_initializer=tf.keras.initializers.GlorotUniform()
)
_ = embed_glorot(dummy_input) # เรียกใช้งาน layer เพื่อสร้าง weights
weights_glorot = embed_glorot.get_weights()[0].flatten()
weights_glorot.shape
# Out:
# (100000,)

# %%
fig = make_subplots(rows=1, cols=1)

fig.add_trace(go.Histogram(x=weights_default, nbinsx=50, name="Default Uniform [-0.05, 0.05]", opacity=0.6))
fig.add_trace(go.Histogram(x=weights_glorot, nbinsx=50, name="Glorot Uniform", opacity=0.6))

fig.update_layout(
    title_text='Embedding Layer Initialization Comparison',
    xaxis_title_text='Weight values',
    yaxis_title_text='Frequency',
    barmode='overlay',
    legend_orientation="h",
    legend_yanchor="bottom",
    legend_y=1.02,
    legend_xanchor="right",
    legend_x=1
)

fig.show()

print("Default initializer range ", weights_default.min(), weights_default.max())
print("Glorot initializer range ", weights_glorot.min(), weights_glorot.max())
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="1105fb50-40d7-46e3-b2e6-5c3d0cfbc01c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1105fb50-40d7-46e3-b2e6-5c3d0cfbc01c")) {                    Plotly.newPlot(                        "1105fb50-40d7-46e3-b2e6-5c3d0cfbc01c",                        [{"name":"Default Uniform [-0.05, 0.05]","nbinsx":50,"opacity":0.6,"x":[0.02308872,-0.047813453,0.028685834,0.02032343,-0.04107809,0.0042700283,-0.04266056,-0.04981338,0.034274448,-0.04546387,-0.005071737,0.04539642,-0.0427418,-0.041250207,-0.0055255406,0.019904185,-0.012824941,0.03823414,-0.042454746,0.041467134,0.04600415,-0.0027484074,0.034061562,-0.048096396,-0.012504924,-0.04637437,-0.048092987,-0.046619203,-0.0024626255,-0.047415353,0.02157661,0.043903027,0.03691927,-0.0155502185,-0.041817248,0.041954983,-0.004558623,-0.029549373,-0.04117558,-0.019284546,0.028704833,0.013517689,0.03304216,0.03923488,-0.033931375,0.014294829,-0.038005054,-0.0020849109,-0.04575925,0.037125316,-0.03696978,0.0055825487,0.047319304,0.019750621,0.032514762,-0.022382796,0.0066779032,0.012876693,0.011025868,0.03252418,-0.01232481,0.04265443,0.02521262,-0.048447084,-0.021200467,-0.0068548694,0.048992563,-0.00079882145,-0.024508977,0.028938923,0.042489637,-0.04480741,-0.017186653,0.0017785542,-0.0127443075,-0.0078323,0.009690203,-0.027356649,0.02768505,-0.008772779,-0.039866306,-0.03356649,-0.03918444,0.03834394,0.049360525,0.018254329,-0.039175797,0.0044348016,-0.023058092,0.026864257,0.03155409,0.000248231,0.0313001,0.0013199337,0.033338655,0.030068029,-0.023872484,-0.020479226,0.015050698,0.024916079,-0.009229612,0.005274914,0.0028994903,-0.01821183,-0.032965768,-0.022742784,0.041610252,0.041354965,-0.03687934,0.006212402,-0.048642527,-0.017568447,-0.047664404,-0.034579884,-0.023301138,0.026879106,-0.040687013,-0.012976408,0.030525494,0.031481747,0.026980285,0.008128129,-0.024042679,0.035387542,-0.015424095,-0.010692202,-0.008451689,0.04947977,0.02367599,0.019764666,-0.04767418,0.027620088,0.020368662,-0.015937913,0.016413938,0.029542971,-0.04958296,-0.03969251,-0.0077277534,-0.02467866,-0.041737687,-0.03519287,0.010389961,-0.032479405,-0.041796543,0.032747176,-0.005713057,-0.015715577,-0.017915703,0.04130132,-0.0483572,0.028789882,-0.03352268,-0.010160148,0.012223173,-0.014501322,-0.015912067,0.042979192,0.041688908,0.015921,0.04417641,0.029271651,-0.013976894,0.0319202,-0.0010625497,0.03739233,0.033015583,0.011470806,0.017407227,0.022810373,0.0059390552,-0.024383307,0.03517696,-0.011855554,0.042855207,0.0026438944,0.009429861,-0.0089859255,0.01636858,-0.008007072,-0.023417903,-0.008582272,0.005476225,-0.03583791,0.00768758,0.026865032,-0.044826746,0.0048155673,-0.032137953,0.000943698,0.015703116,-0.040667105,-0.04730883,0.041021053,-0.0059232004,0.008778334,-0.00053905323,0.0389984,0.02578533,0.046218563,0.002459146,0.021188546,-0.031883705,-0.030763542,0.0009303577,0.018917684,-0.041780245,-0.008149959,-0.02517779,0.03438202,-0.019934356,0.047463465,-0.018323041,-0.031737126,0.0038309917,-0.010004986,0.030843724,0.040746298,-0.017236184,0.00050021335,-0.027309848,-0.020941233,0.020421948,-0.048011996,-0.004481185,-0.00023292378,-0.045694064,0.020202111,0.02318808,0.021720972,-0.013689399,-0.017106403,-0.03726679,0.049807157,0.008863162,0.015521061,-0.032373868,0.02854688,0.04725789,-0.008896947,0.04656856,0.012057424,-0.027341414,-0.0015088432,0.035074297,-0.039857376,-0.029433811,-0.015496243,0.036495138,0.0011903532,0.043820534,0.02565967,-0.042572536,0.031077947,-0.03884325,0.0025657043,-0.0045651197,0.03624847,-0.019153034,-0.04241395,0.025267903,-0.009391628,0.029885981,0.031141166,0.049941268,-0.022586977,0.017580453,0.001934696,-0.02321948,0.036061276,0.04212166,-0.032597445,-0.032 ...
# Default initializer range  -0.049999632 0.049997423
# Glorot initializer range  -0.010953976 0.0109542115

# %%
def glorot_uniform_limits(fan_in, fan_out):
    limit = math.sqrt(6.0 / (fan_in + fan_out))
    a, b = -limit, limit
    return a, b

# ตัวอย่าง Embedding layer (vocab_size=50000, embedding_dim=2)
fan_in = 50000
fan_out = 2

a, b = glorot_uniform_limits(fan_in, fan_out)
print("Glorot Uniform a =", a)
print("Glorot Uniform b =", b)
# Out:
# Glorot Uniform a = -0.010954232067652772
# Glorot Uniform b = 0.010954232067652772

# %%
model = AutoModelForSeq2SeqLM.from_pretrained(checkpoint)
# Out:
# config.json:   0%|          | 0.00/846 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/2.46G [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.46G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/189 [00:00<?, ?B/s]

# %%
token_embedding_layer = model.model.encoder.embed_tokens
token_embedding_layer.weight.shape
# Out:
# torch.Size([256206, 1024])

# %%
long_sentence = "In the vast realm of natural language processing, understanding the nuances of how models handle sequential data is crucial. Positional encoding plays a vital role in providing this essential information to the model, allowing it to differentiate between words at different positions in a sentence, which is fundamental for tasks like translation, summarization, and text generation."

# %%
tokens = tokenizer(long_sentence, return_tensors="pt")

print(tokens['input_ids'][0])
# Out:
# tensor([256047,    717,    349,  14430,  12284, 248070,    452,  25307,  65445,
#         157278, 248079, 133930,    349,    713,  75831,    452,  11657, 141057,
#          47274, 116914, 124785,   6067,    248, 182071, 248075,  12013,  58409,
#          12025, 246156,   3054,    705,      9, 104781,  76065,    108, 174693,
#           3423, 140515,  18781,    202,    349,  14916, 248079,  82935,     87,
#            796,    202,  53054,    502,  25914,  51744,    230,  30158, 199073,
#            108,      9, 109267, 248079,   9089,    248,  75529,    351, 226047,
#           6399, 200356, 248079,   2493, 109207, 181953, 248079,    540,  35883,
#         120531, 248075,      2])

# %%
len(tokens['input_ids'][0])
# Out:
# 75

# %%
token_embedding_layer(tokens['input_ids'][0][0]).shape
# Out:
# torch.Size([1024])

# %%
token_embeddings = token_embedding_layer(tokens['input_ids'][0])

print("Token Embedding Matrix shape", token_embeddings.shape)
token_embeddings
# Out:
# Token Embedding Matrix shape torch.Size([75, 1024])
# tensor([[-5.0000e+00, -1.2725e+00, -9.3604e-01,  ..., -1.8297e+01,
#          -9.1328e+00, -1.0672e+01],
#         [ 2.6416e-01,  2.6831e-01,  2.0117e-01,  ...,  3.2715e+00,
#          -3.2402e+00,  3.1738e+00],
#         [ 4.3579e-01, -2.3352e-01,  2.6825e-02,  ...,  5.4648e+00,
#           2.7129e+00,  5.5430e+00],
#         ...,
#         [ 8.5859e+00, -4.5391e+00, -4.7314e-01,  ..., -7.9529e-02,
#           7.4844e+00, -7.5156e+00],
#         [-2.4863e+00, -2.7515e-01,  5.6114e-03,  ...,  1.0180e+01,
#          -7.2422e+00, -4.8047e+00],
#         [-7.8320e-01, -9.0527e-01, -9.4482e-01,  ...,  3.1078e+01,
#          -8.1494e-01, -8.7354e-01]], grad_fn=<MulBackward0>)

# %%
import plotly.express as px

token_embeddings_np = token_embeddings.detach().numpy()

fig = px.imshow(
    token_embeddings_np,
    color_continuous_scale="RdBu",
    labels=dict(x="Embedding Dimension", y="Token Index", color="Value"),
    title="Token Embedding Heatmap"
)

fig.update_xaxes(side="top")
fig.update_layout(height=500, width=900)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="744e2a06-ca0c-412b-bb0b-69f0d37dc9a9" class="plotly-graph-div" style="height:500px; width:900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("744e2a06-ca0c-412b-bb0b-69f0d37dc9a9")) {                    Plotly.newPlot(                        "744e2a06-ca0c-412b-bb0b-69f0d37dc9a9",                        [{"coloraxis":"coloraxis","name":"0","z":[[-5.0,-1.2724609,-0.93603516,-0.83203125,-2.8164062,-1.4824219,-1.4541016,-1.5322266,-2.0976562,-1.3632812,-1.3916016,-0.8466797,-0.40673828,-2.1171875,-2.9785156,-5.9257812,-3.2480469,-3.2265625,-5.4296875,-4.6445312,-4.6210938,-2.7578125,1.6699219,0.23669434,2.6699219,0.6894531,2.1640625,-1.4003906,-1.5332031,1.078125,0.27319336,-0.044677734,-4.484375,2.7148438,-0.82714844,-0.9248047,-1.4833984,1.5966797,0.3942871,2.7675781,-0.18151855,-1.4208984,1.4765625,-3.5234375,-1.9033203,-0.36523438,-3.0449219,-7.0078125,3.3378906,-2.4453125,-1.21875,0.6464844,-0.20788574,0.50927734,-0.35546875,2.6171875,-1.484375,-7.21875,-1.6210938,-4.1679688,-6.3476562,0.6245117,-0.8540039,-0.36621094,0.53759766,-4.03125,-1.4160156,-1.6035156,-0.20056152,-2.6367188,0.5800781,-4.2421875,-1.0517578,1.6572266,-3.7011719,-2.1425781,-2.3203125,-0.46142578,-3.1484375,-3.5039062,5.1484375,1.5410156,-2.4667969,1.8359375,-0.8930664,1.2636719,-2.5976562,1.8720703,-1.9160156,1.6894531,-0.9248047,-3.6503906,-2.6464844,3.9433594,-1.8027344,0.08276367,-2.3632812,-0.3720703,-1.2607422,-1.0986328,0.82666016,-2.9101562,-0.7949219,3.4023438,3.4804688,-5.0664062,1.2001953,-2.8222656,-0.0925293,-0.06573486,-4.15625,-0.24804688,-5.2421875,-5.2070312,-1.1210938,-2.1269531,-0.9296875,1.3291016,0.5756836,3.2910156,0.028930664,-3.2949219,-0.74902344,1.9746094,3.2324219,-2.9824219,-4.078125,2.9355469,-0.37890625,-6.0429688,-1.1982422,5.2929688,-0.9555664,-1.0087891,-2.4609375,-2.8320312,7.0390625,1.34375,6.0195312,-4.3007812,-0.33691406,1.3554688,1.9746094,0.88964844,-0.8432617,-1.1689453,2.0429688,-3.375,-2.2167969,-1.0732422,-6.8984375,5.59375,0.70751953,-2.4511719,1.0996094,2.953125,1.5742188,0.7495117,-4.53125,-2.7207031,2.3007812,0.19958496,1.5048828,-2.625,4.9140625,1.2363281,-1.4033203,-0.7739258,2.9023438,-1.9794922,0.5097656,-5.03125,4.3164062,-1.4628906,-3.6289062,7.9023438,-5.4101562,-0.79541016,1.2724609,-3.03125,-3.2617188,-0.7285156,9.453125,6.8710938,-0.78027344,0.8461914,-0.028656006,-1.4453125,-0.89697266,0.20361328,-5.5234375,-3.1992188,0.09460449,5.4921875,-2.9335938,5.6484375,0.92285156,2.1542969,-3.6738281,-2.5722656,-5.1953125,-4.4296875,6.0625,2.1171875,-0.19140625,2.3886719,-2.3144531,-1.4082031,1.1728516,9.0859375,-5.3789062,-0.14526367,-3.1972656,1.8076172,0.8041992,2.4199219,-0.009849548,-6.2070312,-1.6171875,-3.8027344,2.0898438,-2.5351562,0.86816406,0.17224121,-0.5800781,3.7070312,1.9980469,5.015625,-1.7001953,-0.2734375,-1.4921875,3.2675781,-1.4570312,-3.8964844,-1.7021484,-5.0351562,2.5410156,-4.4414062,-2.9394531,9.359375,-0.703125,-0.5439453,-11.515625,4.1367188,6.640625,2.7636719,-2.6054688,-0.5625,1.6259766,0.94140625,0.2746582,0.24401855,-5.3671875,4.6367188,-5.25,6.1484375,-5.5429688,-0.3149414,-2.1875,-2.0859375,-1.1806641,7.3671875,-0.17993164,-1.1494141,-15.9296875,-1.5449219,-3.7226562,-4.6484375,3.0507812,5.1835938,-2.4550781,3.71875,-0.9057617,8.40625,0.1361084,-4.65625,3.203125,0.28466797,-7.28125,-2.9941406,-5.0625,0.92578125,-12.6796875,-5.2929688,0.47802734,18.0625,-11.078125,3.34375,-3.3222656,0.3605957,-6.3164062,-17.1875,3.6796875,-4.4257812,-8.4375,-6.2578125,16.046875,-4.4570312,0.10467529,0.18127441,-4.0664062,-0.4375,1.3125,-1.5859375,-3.6503906,-5.1875,0.32910156,-3.6367188,-3.1835938,-1.5380859,-2.1601562,2.2910156,2.0507812,4.1367188,3.1503906,-0.33325195,-0.03668213,0.8671875,-2.8515625,-7.3359375,-2.9296875,-4.6015625,0.0 ...

# %%
d = embedded_sentence.shape[-1]
d
# Out:
# 2

# %%
d_q, d_k, d_v = 2, 2, 4

d_q, d_k, d_v
# Out:
# (2, 2, 4)

# %%
tf.random.set_seed(123)
W_query = tf.Variable(tf.random.uniform((d, d_q)), trainable=True)
W_key   = tf.Variable(tf.random.uniform((d, d_k)), trainable=True)
W_value = tf.Variable(tf.random.uniform((d, d_v)), trainable=True)

# %%
print(W_query.shape, W_key.shape, W_value.shape)
# Out:
# (2, 2) (2, 2) (2, 4)

# %%
W_query
# Out:
# <tf.Variable 'Variable:0' shape=(2, 2) dtype=float32, numpy=
# array([[0.12615311, 0.5727513 ],
#        [0.2993133 , 0.5461836 ]], dtype=float32)>

# %%
W_key
# Out:
# <tf.Variable 'Variable:0' shape=(2, 2) dtype=float32, numpy=
# array([[0.88968754, 0.12354946],
#        [0.7718717 , 0.6850728 ]], dtype=float32)>

# %%
W_value
# Out:
# <tf.Variable 'Variable:0' shape=(2, 4) dtype=float32, numpy=
# array([[0.48962688, 0.5857923 , 0.36451697, 0.6550509 ],
#        [0.9075084 , 0.37557673, 0.6882372 , 0.25384045]], dtype=float32)>

# %%
embedded_sentence
# Out:
# <tf.Tensor: shape=(4, 2), dtype=float32, numpy=
# array([[ 0.04274413,  0.02640809],
#        [ 0.04193771,  0.01141412],
#        [-0.01925882,  0.01812642],
#        [ 0.01571875,  0.02884904]], dtype=float32)>

# %%
queries = tf.matmul(embedded_sentence, W_query)
keys    = tf.matmul(embedded_sentence, W_key)
values  = tf.matmul(embedded_sentence, W_value)

# %%
print("Queries shape", queries.shape)
queries
# Out:
# Queries shape (4, 2)
# <tf.Tensor: shape=(4, 2), dtype=float32, numpy=
# array([[ 0.0132966 ,  0.03890542],
#        [ 0.00870697,  0.03025408],
#        [ 0.00299592, -0.00113016],
#        [ 0.01061787,  0.0247598 ]], dtype=float32)>

# %%
print("Keys shape", keys.shape)
keys
# Out:
# Keys shape (4, 2)
# <tf.Tensor: shape=(4, 2), dtype=float32, numpy=
# array([[ 0.05841257,  0.02337248],
#        [ 0.0461217 ,  0.01300089],
#        [-0.00314306,  0.0100385 ],
#        [ 0.03625253,  0.02170573]], dtype=float32)>

# %%
print("Values shape", values.shape)
values
# Out:
# Values shape (4, 4)
# <tf.Tensor: shape=(4, 4), dtype=float32, numpy=
# array([[ 0.04489423,  0.03495744,  0.03375599,  0.03470302],
#        [ 0.03089224,  0.02885367,  0.02314263,  0.0303687 ],
#        [ 0.00702024, -0.00447381,  0.00545511, -0.00801429],
#        [ 0.03387707,  0.02004295,  0.02558473,  0.01761963]],
#       dtype=float32)>

# %%
omega = tf.matmul(queries, keys, transpose_b=True)

print("Omega shape", omega.shape)
print("Omega (Unnormalized attention weights)")
print(omega)
# Out:
# Omega shape (4, 4)
# Omega (Unnormalized attention weights)
# tf.Tensor(
# [[ 1.6860045e-03  1.1190665e-03  3.4875990e-04  1.3265058e-03]
#  [ 1.2157096e-03  7.9491024e-04  2.7633904e-04  9.7233686e-04]
#  [ 1.4858453e-04  1.2348368e-04 -2.0761508e-05  8.4078558e-05]
#  [ 1.1989151e-03  8.1161363e-04  2.1517860e-04  9.2235440e-04]], shape=(4, 4), dtype=float32)

# %%
d_k = tf.cast(d_k, tf.float32)

scaled_omega = omega / tf.sqrt(d_k)

attention_weights = tf.nn.softmax(scaled_omega, axis=-1)

print("Attention Weights")
print(attention_weights)
# Out:
# Attention Weights
# tf.Tensor(
# [[0.25010005 0.24999982 0.24986367 0.25003648]
#  [0.25007087 0.24999648 0.24990483 0.25002784]
#  [0.25001144 0.250007   0.24998151 0.25000003]
#  [0.25007284 0.25000435 0.24989893 0.25002393]], shape=(4, 4), dtype=float32)

# %%
row_sums = tf.reduce_sum(attention_weights, axis=-1)

print("Sum of each row in attention_weights")
row_sums
# Out:
# Sum of each row in attention_weights
# <tf.Tensor: shape=(4,), dtype=float32, numpy=array([1., 1., 1., 1.], dtype=float32)>

# %%
context_vector = tf.matmul(attention_weights, values)

print("Context Vector shape", context_vector.shape)
print(context_vector)
# Out:
# Context Vector shape (4, 4)
# tf.Tensor(
# [[0.02917571 0.0198499  0.02198818 0.01867447]
#  [0.02917429 0.01984842 0.02198712 0.01867287]
#  [0.02917155 0.01984575 0.02198506 0.01867002]
#  [0.02917445 0.01984867 0.02198724 0.01867316]], shape=(4, 4), dtype=float32)

# %%
class SelfAttention(tf.keras.layers.Layer):
    def __init__(self, d_in, d_out_kq, d_out_v):
        super().__init__()
        self.d_out_kq = d_out_kq

        self.W_query = tf.Variable(
            tf.random.uniform((d_in, d_out_kq)), trainable=True
        )
        self.W_key = tf.Variable(
            tf.random.uniform((d_in, d_out_kq)), trainable=True
        )
        self.W_value = tf.Variable(
            tf.random.uniform((d_in, d_out_v)), trainable=True
        )

    def call(self, x):
        keys = tf.matmul(x, self.W_key)      # [T, d_out_kq]
        queries = tf.matmul(x, self.W_query) # [T, d_out_kq]
        values = tf.matmul(x, self.W_value)  # [T, d_out_v]

        # Attention scores: QKᵀ
        attn_scores = tf.matmul(queries, keys, transpose_b=True)  # [T, T]

        # Softmax (scaled by sqrt(d_k))
        attn_weights = tf.nn.softmax(
            attn_scores / tf.math.sqrt(tf.cast(self.d_out_kq, tf.float32)), axis=-1
        )  # [T, T]

        # Weighted sum
        context_vec = tf.matmul(attn_weights, values)  # [T, d_out_v]
        return context_vec

# %%
tf.random.set_seed(123)

d_in, d_out_kq, d_out_v = 2, 2, 4

sa = SelfAttention(d_in, d_out_kq, d_out_v)

out = sa(embedded_sentence)

print(out.shape)  # (T, d_out_v)
print(out.numpy())
# Out:
# (4, 4)
# [[0.02917571 0.0198499  0.02198818 0.01867447]
#  [0.02917429 0.01984842 0.02198712 0.01867287]
#  [0.02917155 0.01984575 0.02198506 0.01867002]
#  [0.02917445 0.01984867 0.02198724 0.01867316]]

# %%
class MultiHeadAttentionWrapper(tf.keras.layers.Layer):
    def __init__(self, d_in, d_out_kq, d_out_v, num_heads):
        super().__init__()
        self.heads = [
            SelfAttention(d_in, d_out_kq, d_out_v)
            for _ in range(num_heads)
        ]

    def call(self, x):
        # รันทุก head แล้ว concat ตามแกนสุดท้าย
        head_outputs = [head(x) for head in self.heads]   # list of [T, d_out_v]
        return tf.concat(head_outputs, axis=-1)           # [T, num_heads * d_out_v]

# %%
tf.random.set_seed(123)

d_in, d_out_kq, d_out_v = 2, 2, 1

sa = SelfAttention(d_in, d_out_kq, d_out_v)

# ถ้า embedded_sentence.shape = [T, d_in] เช่น [6, 3]
out = sa(embedded_sentence)

print(out.shape)   # (T, d_out_v) -> (6, 1)
print(out.numpy())
# Out:
# (4, 1)
# [[0.02235512]
#  [0.02235381]
#  [0.02235134]
#  [0.02235399]]

# %%
tf.random.set_seed(123)

mha = MultiHeadAttentionWrapper(
    d_in, d_out_kq, d_out_v, num_heads=3
)

# run MHA
context_vecs = mha(embedded_sentence)   # [T, num_heads * d_out_v]

print(context_vecs)
print("context_vecs.shape:", context_vecs.shape)
# Out:
# tf.Tensor(
# [[0.02235512 0.02721053 0.03443892]
#  [0.02235381 0.027208   0.03443808]
#  [0.02235134 0.02719756 0.03442376]
#  [0.02235399 0.02720584 0.03443258]], shape=(4, 3), dtype=float32)
# context_vecs.shape: (4, 3)
